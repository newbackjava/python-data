# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
# !pip install bs4 #cmd에서 이 명령문을 실행!!(코랩)
# pip install bs4 #cmd에서 이 명령문을 실행!!(가상환경)

# %%
con = request.urlopen('https://hottracks.kyobobook.co.kr/')
con
#http response(header + body)
#header : http result status code
#         (ok: 200, not found: 404, error: 500, permission: 403)

# %%
con.status #status code
# Out:
# 200

# %%
doc = BeautifulSoup(con, 'html.parser')
#doc

# %%
a_tag_list = doc.select('a.gnb_link')
a_tag_list
# Out:
# [<a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-700 text-red-800" href="https://event.kyobobook.co.kr/detail/240757" target="_self">블프특가<span class="h-1 w-1 rounded-full bg-red-800"></span></a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-700 text-red-800" href="https://hottracks.kyobobook.co.kr/media" target="_self">음반·영상<span class="h-1 w-1 rounded-full bg-red-800"></span></a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-700 text-red-800" href="https://hottracks.kyobobook.co.kr/gift/today-deals" target="_self">오늘만특가<span class="h-1 w-1 rounded-full bg-red-800"></span></a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-700 text-red-800" href="https://event.kyobobook.co.kr/make/239097" target="_self">주말특가<span class="h-1 w-1 rounded-full bg-red-800"></span></a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://hottracks.kyobobook.co.kr/bestseller/gift/daily" target="_self">베스트</a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://hottracks.kyobobook.co.kr/new-releases/gift" target="_self">신상품</a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://hottracks.kyobobook.co.kr/event/promotion" target="_self">이벤트</a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://event.kyobobook.co.kr/funding" target="_self">바로펀딩💡</a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://event.kyobobook.co.kr/detail/241221" target="_self">좋아서EP.3📖</a>,
#  <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-500 text-gray-800" href="https://event.kyobobook.co.kr/detail/239509" target="_self">Only Kyobo📌</a>]

# %%
type(a_tag_list)
# Out:
# bs4.element.ResultSet

# %%
#리스트의 갯수
len(a_tag_list)
# Out:
# 10

# %%
a_tag_list[0]
# Out:
# <a class="gnb_link fz-16 flex items-start gap-0.5 text-nowrap fw-700 text-red-800" href="https://event.kyobobook.co.kr/detail/240757" target="_self">블프특가<span class="h-1 w-1 rounded-full bg-red-800"></span></a>

# %%
a_tag_list[0].text
# Out:
# '블프특가'

# %%
for one in a_tag_list:
    print(one.text)
# Out:
# 블프특가
# 음반·영상
# 오늘만특가
# 주말특가
# 베스트
# 신상품
# 이벤트
# 바로펀딩💡
# 좋아서EP.3📖
# Only Kyobo📌

# %%
anav_list = []

# %%
for one in a_tag_list:
    anav_list.append(one.text)

# %%
anav_list
# Out:
# ['블프특가',
#  '음반·영상',
#  '오늘만특가',
#  '주말특가',
#  '베스트',
#  '신상품',
#  '이벤트',
#  '바로펀딩💡',
#  '좋아서EP.3📖',
#  'Only Kyobo📌']
