# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import datetime

#from selenium import webdriver
import time

# %%
url = "https://www.naver.com"

# 1) URL에 접속해서 HTML 가져오기
html = urllib.request.urlopen(url)

# 2) BeautifulSoup 객체로 파싱
soup = BeautifulSoup(html, "html.parser")

# 3) 전체 HTML 출력
print(soup)
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_251001.css" rel="stylesheet"/> <link href="https://www.naver.com/" rel="canonical"/> <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"쓰레기의 법칙부터 별정직 공무원, 화산귀환까지","url":"https://brand.naver.com/webtoonfriends/category/0c3ebd3a12f14862ac8741b812ab4f71?cp=1","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251120_1095/upload_1763641814451PWmth.jpg"},"highlight":"웹툰프렌즈 팡팡위크","title2":"특별판 오픈!","source":{"name":"더 자세한 내용 만나보기"},"_id":"68c3b0ddeaf13652d094140c"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"전집부터 사운드북까지","url":"https://shopping.naver.com/festa/onsale/68c0e103d6bdc9272d53f786","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251117_1095/upload_1763357034585DYKdU.jpg"},"highlight":"인플루언서 픽!","title2":"육아 인플루언서 추천 도서 특가 기획전","source":{"name":"더 자세한 내용 만나보기"},"_id":"68c3b0ddeaf13652d094140d"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"layout":"BIG-IMAGE-2","orderRandom":false,"_id":null,"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-CULTURE-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"미래엔 사회1 + 과학1 평가문제집 세트 중1 중등 (전 2권)","url":"https://msearch.shopping.naver.com/book/catalog/52955563311","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5295556%2F52955563311.20250214073917.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"미래엔콘텐츠연구회","service":"미래엔"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b727"},{"@type":"MATERIAL-PC-FEED","title":"미래가 보이는 일기장","url":"https://msearch.shopping.naver.com/book/catalog/57198017844","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5719801%2F57198017844.20251015071929.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"고혜원","service":"다이브"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b728"},{"@type":"MATERIAL-PC-FEED","title":"2026 사이다 면접","url":"https://msearch.shopping.naver.com/book/catalog/57441840709","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5744184%2F57441840709.20251031071131.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"이지수, 구영모","service":"박문각"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b729"},{"@type":"MATERIAL-PC-FEED","title":"오늘의 제철 행복","url":"https://msearch.shopping.naver.com/book/catalog/57024001963","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5702400%2F57024001963.20251003080724.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"김신지","service":"인플루엔셜"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72a"},{"@type":"MATERIAL-PC-FEED","title":"나노 바나나","url":"https://msearch.shopping.naver.com/book/catalog/57259885634","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5725988%2F57259885634.20251017092849.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"문수민, 박범희, 앤미디어","service":"생능북스"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72b"},{"@type":"MATERIAL-PC-FEED","title":"아이가 완밥하는 솥밥 유아식","url":"https://msearch.shopping.naver.com/book/catalog/57298841619","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5729884%2F57298841619.20251021093447.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"비비안밥(이지혜)","service":"길벗"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72c"},{"@type":"MATERIAL-PC-FEED","title":" ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"beb391b7-c683-11f0-b431-63dd8157c18b","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,39,127000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:29:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251120 17:57:23","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:21:01","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251120 15:13:14","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:30:39","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 09:36:47","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:30:28","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[2보] 해병특검, '채상병 수사외압' 윤석열·이종섭 등 12명 기소","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755609","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[2보] 내란특검, 한덕수 전 총리 소환…'헌법재판관 미임명 의혹'","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755643","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"김건희특검, 감사원 또 압수수색…'관저이전 특혜' 자료확보","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755486","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"박철우 중앙지검장 취임 \"보완수사, 검찰 인정받을 중요분야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755549","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"李대통령 지지율, 전주 대비 1%p 올라 60%…민주 43%·국힘 24%[한국갤럽]","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755608","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"내년 지선 '與후보 많이 당선' 42%, '野후보 다수' 35%[한국갤럽]","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755726","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"683f13f2f74934e40c0fed6b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"해경, '휴대전화 딴짓' 여객선 좌초 항해사·조타수 구속영장","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755760","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db37e6cdff968ea897472f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'대출절벽' 현실로…KB도 올해 실행 주택구입 가계대출 중단","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755297","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db3a029fd064e40518502f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"총리실 '헌법존중 총괄TF' 가동…\"신속하게 헌정질서 회복\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755563","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"690b14cad1344152dbca61e7"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"삼성 ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowovLrTH3IhSlnGBp%2BzsjSYJ32BzbuaPZvCGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=s6fx-TNIGmzushGzk5K5bQ&eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"68414a73a10d30068523e7ee","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"b12766cd-c683-11f0-b431-d112c329a958","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,16,459000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"bdaa5f9e-c683-11f0-ba85-a33eb7c7621e","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,37,393000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N011","adlineId":null,"vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FIvLrTH3IhSlnGBp%2BzsjSYJ32BzbuaPZvCGNcbrnFmKn&ac=8968387&src=7094288&evtcd=V900&x_ti=1586&tb=&oid=&sid1=&sid2=&rk=mivOWRRlKvtnFF6ktNsu3g&eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D&brs=Y&&eid=V900","assets":null},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c4d05bce-c683-11f0-b431-138a90e32607","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,49,398000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ba1662d1-c683-11f0-9de7-2d9f4678ba89","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,31,377000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c7337931-c683-11f0-b431-1516755b768c","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,53,388000000]}
# </script>
# <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.de9c70b5.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.baeef60d.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.1c8f328c.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.ae1c7fcd.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.07f20d10.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"49715c62cc854717942293e4804ae58d","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":43,"adDivId":"ad_timeboard","ads":[{"encrypted":"5vQ81zaiPqN0l6_3Abdclgp7S5wOJctKvS6i96gUTzNxGFU8l1pRktUcPFwaM3PNCPG7FykT8p869ZOGoMfiK-GoR-WGfzZqEXPenayq-mwgg77RJqZDDsMK95UX8KSaAaUZDIJRzDyt-jhgK2q53SQdZc7Na9Peoaa20ZW9oPRs5YgD8GBLg_L-2ODZeWQUEOWl7LBKzl7DssCt197xtlO5t_xZ3wpzdSLCbOS6_N4fBjwv5-ruV5DrUxp4v4b1zQGnT34uUCqO82gZLhwPVXVVCJLcputLZ78-nVLGk708mvdz62ZWqz6VL5Mjrd0Q-C0BCNuCbVHF2Mnd5K8D-yUq5FcXtZsY1D264zmZrIF2s4B4RagrBGIuIJr-uB75cb3LCJUQgYxCSSPMdvl7v4MtKXJE5YO2ZKfA2MIA0rGksI4NpFq3PQfSHI0-vfnVfNfWK0jpE8yEhB55fyMHSfU199OQJPF00KfNHCDY4U7XgDcklpIZGxwCl9pNPLuJxb8hMSdSUiczrTS93sJJjoVFKEacNdiTMJvq9JKRJX58h2snTZF-kcelPv2dhfpz_dUOcxsve0giZ1oxmKUz9zbZVRKrUEaQtmqEadS07sKF5JJXYzCrSzkZhLaU6RbZcQHuqlSgIx70W1r1Q4453tmjq6cFdNtnOAmt-7iCzCO6lcHecBckyuuvf23liPjNyGxo6qlRriI37RC7-Ccj9A==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5Mih4oX7F06T8SOjfo%2FCMjrgFkGF1Xqa7oAWsW5VKuRENAS9RmV%2B2y%2BJL1qM2Pf%2FamLy60x9yIUpZxgafs7I0mCd9gc27mj2byeBJzbEUemkkplqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb10wXXPTxP9fUvtBMhB%2F95FF8ugsnigZsy9gvmfFyhM0\u0026ac=9211493\u0026src=7887099\u0026evtcd=BID_WIN\u0026x_ti=1504\u0026rk=31PPM4VNcfvpAFYF4Ye77A\u0026eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[],"priv":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","cid":"1550023","crid":"2812021","exp":991,"adContext":"{\"id\":\"49715c62cc854717942293e4804ae58d\",\"impId\":\"BR0_I0\",\"adProviderName\":\"NDP_SF\",\"cid\":[\"1550023\"],\"crid\":[\"2812021\"],\"crea ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="width:1280px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div class="ad_premium_area" id="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div> <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20251121114327',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),l=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(l&&l.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),l&&l.setAttribute("class","ico_btn_search type_color"),l&&l.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var l=Math.floor(Math.random()*e.items.length),s=e.items[l];e.items=[s];const o=s&&s.content?s.content.input:null;t(o&&o.color);const i=document.getElementById("search"),n=i&&(!o||!o.showSearchLogo);n&&i.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?n&&i.classList.remove("type_special_logo_full"):n&&i.classList.add("type_special_logo_full")});var r=o&&o.placeholder;if(r){var a=document.getElementById("query");a&&r&&a.setAttribute("title",r),a&&r&&a.setAttribute("placeholder",r)}}()</script> </body> </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
#       <meta content="https://www.naver.com/" name="twitter:url"/>
#       <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#       <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
#        <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification">
#         <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#         <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed">
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#          <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_251001.css" rel="stylesheet"/>
#          <link href="https://www.naver.com/" rel="canonical"/>
#          <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/>
#          <script>
#           window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"
#          </script>
#          <script>
#           window.ntm=window.ntm||[]
#          </script>
#          <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#          </script>
#          <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#          </script>
#          <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#          </script>
#          <script>
#           window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"쓰레기의 법칙부터 별정직 공무원, 화산귀환까지","url":"https://brand.naver.com/webtoonfriends/category/0c3ebd3a12f14862ac8741b812ab4f71?cp=1","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251120_1095/upload_1763641814451PWmth.jpg"},"highlight":"웹툰프렌즈 팡팡위크","title2":"특별판 오픈!","source":{"name":"더 자세한 내용 만나보기"},"_id":"68c3b0ddeaf13652d094140c"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"전집부터 사운드북까지","url":"https://shopping.naver.com/festa/onsale/68c0e103d6bdc9272d53f786","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251117_1095/upload_1763357034585DYKdU.jpg"},"highlight":"인플루언서 픽!","title2":"육아 인플루언서 추천 도서 특가 기획전","source":{"name":"더 자세한 내용 만나보기"},"_id":"68c3b0ddeaf13652d094140d"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"layout":"BIG-IMAGE-2","orderRandom":false,"_id":null,"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-CULTURE-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"미래엔 사회1 + 과학1 평가문제집 세트 중1 중등 (전 2권)","url":"https://msearch.shopping.naver.com/book/catalog/52955563311","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5295556%2F52955563311.20250214073917.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"미래엔콘텐츠연구회","service":"미래엔"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b727"},{"@type":"MATERIAL-PC-FEED","title":"미래가 보이는 일기장","url":"https://msearch.shopping.naver.com/book/catalog/57198017844","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5719801%2F57198017844.20251015071929.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"고혜원","service":"다이브"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b728"},{"@type":"MATERIAL-PC-FEED","title":"2026 사이다 면접","url":"https://msearch.shopping.naver.com/book/catalog/57441840709","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5744184%2F57441840709.20251031071131.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"이지수, 구영모","service":"박문각"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b729"},{"@type":"MATERIAL-PC-FEED","title":"오늘의 제철 행복","url":"https://msearch.shopping.naver.com/book/catalog/57024001963","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5702400%2F57024001963.20251003080724.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"김신지","service":"인플루엔셜"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72a"},{"@type":"MATERIAL-PC-FEED","title":"나노 바나나","url":"https://msearch.shopping.naver.com/book/catalog/57259885634","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5725988%2F57259885634.20251017092849.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"문수민, 박범희, 앤미디어","service":"생능북스"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72b"},{"@type":"MATERIAL-PC-FEED","title":"아이가 완밥하는 솥밥 유아식","url":"https://msearch.shopping.naver.com/book/catalog/57298841619","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5729884%2F57298841619.20251021093447.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"비비안밥(이지혜)","service":"길벗"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72c"},{"@type":"MATERIAL-PC-FEED","title":" ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"beb391b7-c683-11f0-b431-63dd8157c18b","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,39,127000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:29:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251120 17:57:23","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:21:01","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251120 15:13:14","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:30:39","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 09:36:47","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251121 11:30:28","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[2보] 해병특검, '채상병 수사외압' 윤석열·이종섭 등 12명 기소","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755609","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[2보] 내란특검, 한덕수 전 총리 소환…'헌법재판관 미임명 의혹'","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755643","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"김건희특검, 감사원 또 압수수색…'관저이전 특혜' 자료확보","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755486","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"박철우 중앙지검장 취임 \"보완수사, 검찰 인정받을 중요분야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755549","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"李대통령 지지율, 전주 대비 1%p 올라 60%…민주 43%·국힘 24%[한국갤럽]","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755608","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"내년 지선 '與후보 많이 당선' 42%, '野후보 다수' 35%[한국갤럽]","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755726","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"683f13f2f74934e40c0fed6b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"해경, '휴대전화 딴짓' 여객선 좌초 항해사·조타수 구속영장","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755760","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db37e6cdff968ea897472f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'대출절벽' 현실로…KB도 올해 실행 주택구입 가계대출 중단","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755297","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db3a029fd064e40518502f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"총리실 '헌법존중 총괄TF' 가동…\"신속하게 헌정질서 회복\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015755563","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"690b14cad1344152dbca61e7"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"삼성 ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowovLrTH3IhSlnGBp%2BzsjSYJ32BzbuaPZvCGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=s6fx-TNIGmzushGzk5K5bQ&eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"68414a73a10d30068523e7ee","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"b12766cd-c683-11f0-b431-d112c329a958","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,16,459000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"bdaa5f9e-c683-11f0-ba85-a33eb7c7621e","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,37,393000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N011","adlineId":null,"vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FIvLrTH3IhSlnGBp%2BzsjSYJ32BzbuaPZvCGNcbrnFmKn&ac=8968387&src=7094288&evtcd=V900&x_ti=1586&tb=&oid=&sid1=&sid2=&rk=mivOWRRlKvtnFF6ktNsu3g&eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D&brs=Y&&eid=V900","assets":null},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c4d05bce-c683-11f0-b431-138a90e32607","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,49,398000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ba1662d1-c683-11f0-9de7-2d9f4678ba89","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,31,377000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c7337931-c683-11f0-b431-1516755b768c","@provider":"lambda","@lastModifiedAt":[2025,11,21,2,42,53,388000000]}
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.de9c70b5.js?o=www">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.baeef60d.js?o=www">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.1c8f328c.js?o=www">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.ae1c7fcd.js?o=www">
#          </script>
#          <link href="https://pm.pstatic.net/resources/css/main.07f20d10.css" rel="stylesheet"/>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="u_skip">
#    <a href="#topAsideButton">
#     <span>
#      상단영역 바로가기
#     </span>
#    </a>
#    <a href="#shortcutArea">
#     <span>
#      서비스 메뉴 바로가기
#     </span>
#    </a>
#    <a href="#newsstand">
#     <span>
#      새소식 블록 바로가기
#     </span>
#    </a>
#    <a href="#shopping">
#     <span>
#      쇼핑 블록 바로가기
#     </span>
#    </a>
#    <a href="#feed">
#     <span>
#      관심사 블록 바로가기
#     </span>
#    </a>
#    <a href="#account">
#     <span>
#      MY 영역 바로가기
#     </span>
#    </a>
#    <a href="#widgetboard">
#     <span>
#      위젯 보드 바로가기
#     </span>
#    </a>
#    <a href="#viewSetting">
#     <span>
#      보기 설정 바로가기
#     </span>
#    </a>
#   </div>
#   <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">
#    {"payload":{"requestId":"49715c62cc854717942293e4804ae58d","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":43,"adDivId":"ad_timeboard","ads":[{"encrypted":"5vQ81zaiPqN0l6_3Abdclgp7S5wOJctKvS6i96gUTzNxGFU8l1pRktUcPFwaM3PNCPG7FykT8p869ZOGoMfiK-GoR-WGfzZqEXPenayq-mwgg77RJqZDDsMK95UX8KSaAaUZDIJRzDyt-jhgK2q53SQdZc7Na9Peoaa20ZW9oPRs5YgD8GBLg_L-2ODZeWQUEOWl7LBKzl7DssCt197xtlO5t_xZ3wpzdSLCbOS6_N4fBjwv5-ruV5DrUxp4v4b1zQGnT34uUCqO82gZLhwPVXVVCJLcputLZ78-nVLGk708mvdz62ZWqz6VL5Mjrd0Q-C0BCNuCbVHF2Mnd5K8D-yUq5FcXtZsY1D264zmZrIF2s4B4RagrBGIuIJr-uB75cb3LCJUQgYxCSSPMdvl7v4MtKXJE5YO2ZKfA2MIA0rGksI4NpFq3PQfSHI0-vfnVfNfWK0jpE8yEhB55fyMHSfU199OQJPF00KfNHCDY4U7XgDcklpIZGxwCl9pNPLuJxb8hMSdSUiczrTS93sJJjoVFKEacNdiTMJvq9JKRJX58h2snTZF-kcelPv2dhfpz_dUOcxsve0giZ1oxmKUz9zbZVRKrUEaQtmqEadS07sKF5JJXYzCrSzkZhLaU6RbZcQHuqlSgIx70W1r1Q4453tmjq6cFdNtnOAmt-7iCzCO6lcHecBckyuuvf23liPjNyGxo6qlRriI37RC7-Ccj9A==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5Mih4oX7F06T8SOjfo%2FCMjrgFkGF1Xqa7oAWsW5VKuRENAS9RmV%2B2y%2BJL1qM2Pf%2FamLy60x9yIUpZxgafs7I0mCd9gc27mj2byeBJzbEUemkkplqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb10wXXPTxP9fUvtBMhB%2F95FF8ugsnigZsy9gvmfFyhM0\u0026ac=9211493\u0026src=7887099\u0026evtcd=BID_WIN\u0026x_ti=1504\u0026rk=31PPM4VNcfvpAFYF4Ye77A\u0026eltts=W%2FmFg0zsSSbAL63C8EopgQ%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[],"priv":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","cid":"1550023","crid":"2812021","exp":991,"adContext":"{\"id\":\"49715c62cc854717942293e4804ae58d\",\"impId\":\"BR0_I0\",\"adProviderName\":\"NDP_SF\",\"cid\":[\"1550023\"],\"crid\":[\"2812021\"],\"creativeType\":\"BANNER\",\"cur\":\"KRW\",\"price\":\"JH0VHMkVsOwUoyByyGjSrT02YRJicy7w07qmaLI=\",\"catType\":\"NCAT\",\"cat\":[\"104\",\"104003\"]}","adm":"%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fscript%3E%0D%0A%0D%0A%3Ca%20href%3D%22https%3A%2F%2Fsiape.veta.naver.com%2Ffxclick%3Feu%3DEU10043565%26calp%3D-%26oj%3DcQgn6aire5Mih4oX7F06T8SOjfo%252FCMjrgFkGF1Xqa7oAWsW5VKuRENAS9RmV%252B2y%252BJL1qM2Pf%252FamLy60x9yIUpZxgafs7I0mCd9gc27mj2byeBJzbEUemkkplqdgUSG%252BUXrQSw%252B%252FX1bbNCF9%252F110BZDp0hCNKO%252BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb10wXXPTxP9fUvtBMhB%252F95FF8ugsnigZsy9gvmfFyhM0%26ac%3D9211493%26src%3D7887099%26br%3D4852720%26evtcd%3DP901%26x_ti%3D1504%26tb%3D%26oid%3D%26sid1%3D%26sid2%3D%26rk%3D31PPM4VNcfvpAFYF4Ye77A%26eltts%3DW%252FmFg0zsSSbAL63C8EopgQ%253D%253D%26brs%3DY%26%22%20id%3D%22ac_banner_a%22%20target%3D%22_blank%22%20style%3D%22display%3Ablock%22%3E%0D%0A%20%20%20%20%3Cimg%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2F1550%2F1550023%2F97db27dcd93bccc2f774_20251117101941459.jpg%22%20width%3D%22830%22%20height%3D%22130%22%20alt%3D%22%5B%EA%B4%91%EA%B3%A0%5D%EC ...
#   </script>
#   <div id="wrap">
#    <div id="header" role="banner">
#     <div class="header_inner" id="topSearchWrap">
#      <div class="search_special_bg" id="special-logo">
#      </div>
#      <div class="ad_area" id="timeboard-ex" style="width:1280px">
#      </div>
#      <div class="search_area" id="search_area" style="border-color:#fff">
#       <div class="search_group">
#        <div class="search_group_inner" id="search">
#         <h1 class="search_logo" id="special-input-logo">
#         </h1>
#         <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search">
#          <fieldset>
#           <legend class="blind">
#            검색
#           </legend>
#           <input name="where" type="hidden" value="nexearch"/>
#           <input id="sm" name="sm" type="hidden" value="top_hty"/>
#           <input id="fbm" name="fbm" type="hidden" value="0"/>
#           <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#           <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#           <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#           <input id="ie" name="ie" type="hidden" value="utf8"/>
#           <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#           <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#           <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#           <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#           <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#           <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#           <div class="search_input_box">
#            <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/>
#           </div>
#           <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit">
#            <span class="ico_btn_search_svg">
#             <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z">
#              </path>
#             </svg>
#            </span>
#            <span class="blind">
#             검색
#            </span>
#           </button>
#          </fieldset>
#         </form>
#         <div class="search_box">
#          <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button">
#           <span class="keybord_text">
#            <span class="blind">
#             입력도구
#            </span>
#           </span>
#          </button>
#          <div id="_nx_kbd" style="display:none">
#          </div>
#          <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button">
#           <span class="blind">
#            자동완성/최근검색어펼치기
#           </span>
#          </button>
#         </div>
#         <div class="layer_atcmp" id="autoFrame" style="display:none">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="search-right">
#      </div>
#      <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation">
#      </div>
#      <div class="menu_area" id="topAsideArea">
#      </div>
#      <div class="pay_area" id="topPayArea">
#      </div>
#      <div class="talk_area" id="topTalkArea">
#      </div>
#      <div class="notify_area" id="topNotiArea">
#      </div>
#      <div class="shopping_area" id="topShoppingArea">
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div class="ad_premium_area" id="ad_premium_area" style="min-width:1920px">
#     </div>
#     <div id="root">
#     </div>
#    </div>
#    <div id="footer" role="contentinfo">
#    </div>
#   </div>
#   <script>
#    window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20251121114327',  };
#   </script>
#   <script>
#    !function(){function t(t){var e=document.getElementById("search_area"),l=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(l&&l.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),l&&l.setAttribute("class","ico_btn_search type_color"),l&&l.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var l=Math.floor(Math.random()*e.items.length),s=e.items[l];e.items=[s];const o=s&&s.content?s.content.input:null;t(o&&o.color);const i=document.getElementById("search"),n=i&&(!o||!o.showSearchLogo);n&&i.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?n&&i.classList.remove("type_special_logo_full"):n&&i.classList.add("type_special_logo_full")});var r=o&&o.placeholder;if(r){var a=document.getElementById("query");a&&r&&a.setAttribute("title",r),a&&r&&a.setAttribute("placeholder",r)}}()
#   </script>
#  </body>
# </html>

# %%
# 1. 접속할 URL
url = "https://news.naver.com/"

# %%
# 2. URL에 요청 보내서 HTML 가져오기
response = urllib.request.urlopen(url)
response

# %%
# 3. BeautifulSoup 객체로 파싱
soup = BeautifulSoup(response, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title id="browserTitleArea">네이버 뉴스</title>
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
# <script>
# 		var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
# <link href="https://ssl.pstatic.net/static.news/mnews/resources/20251029_123353/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script>
# 	(function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
# </script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251029_123353/js/generated/statistics_jquery.js" type="text/javascript"></script>
# <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# <script>
#
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cnb_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#         case "noHeight":
#
#             elImg.outerHTML = '<span class="noimage_wrap"><span class="noimage"></span></span>';
#             break;
#
#         case "displayFallback":
#             elImg.style.display = "none";
#             var elWrapper = elImg.closest("._NOIMAGE_WRAPPER");
#             if (elWrapper) {
#                 var elFallback = elWrapper.querySelector("._NOIMAGE_FALLBACK");
#                 if (elFallback) {
#                     elFallback.style.display = "block";
#                 }
#             }
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
# </script>
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <script>
#
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox_secondary",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
# </script>
# </meta></head>
# <body class="as_mp_layout body_main">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <!-- Menu 구분  -->
# <section class="news_header">
# <header class="nh_header" role="banner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
# <span class="Nicon_family Nicon_entertain">엔터</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search is_hidden _search_content"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb _float_lnb">
# <div class="Nlnb_inner">
# <div class="Nlnb_both">
# <div class="Nlnb_left _lnb_scroll">
# <div class="Nlnb_menu Ntype_scroll">
# <div class="Nlnb_menu_inner _scroll">
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/ombudsman/errorArticleList" onclick="nclk(event,'lnb.correct','','');" role="menuitem"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# </section>
# <hr/>
# <div class="main_wrap" id="ct" role="main">
# <div class="main_container">
# <section class="main_content">
# <h3 class="blind">콘텐츠</h3>
# <div class="main_sublnb">
# <div class="main_sublnb_date">
# <strong>11</strong>.<strong>21</strong><span>(금)</span>
# </div>
# <ul class="main_sublnb_menu">
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">전체 언론사</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">뉴스스탠드</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">라이브러리</a></li>
# </ul>
# </div>
# <div class="main_brick">
# <!-- BRICK HOUSE -->
# <div class="grid1_wrap brick-house _brick_gid_wrapper">
# <div class="brick-vowel _brick_column">
# <div class="main_brick_item _press_main_status_wrapper">
# <div class="comp_journal_subscribe">
# <div class="cjs_title_wrap">
# <h3 class="cjs_edit_title">
# <span class="cjs_main">언론사편집</span>
# <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
# <span class="subs_text">기자
#
#                     </span>
# </a>
# <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
# <span class="subs_text">연재
#
#                     </span>
# </a>
# </h3>
# <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#                 구독설정
#
#                 <span class="ico_more"></span>
# </a>
# </div>
# <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
# <div class="cjs_nf_title">
# <span class="ico_newsflash">속보</span>
# </div>
# <div class="cjs_nf_list _item_list">
# <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/087/0001156430" onclick="nclk(event, 'home.newsflash', '', '')">
# <div class="cn_title_area">
# <h4 class="cn_title">춘천서 자신 소유 승용차에 깔린 60대 사망</h4>
# <div class="cn_snippet">
# <div class="cn_journal_wrap">
# <div class="cn_name">강원일보</div>
# </div>
# </div>
# </div>
# </a>
# <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/659/0000038797" onclick="nclk(event, 'home.newsflash', '', '')">
# <div class="cn_title_area">
# <h4 class="cn_title">조국, '패스트트랙' 1심 선고에 "빠루 들어도 의원직 유지"</h4>
# <div class="cn_snippet">
# <div class="cn_journal_wrap">
# <div class="cn_name">전주MBC</div>
# </div>
# </div>
# </div>
# </a>
# <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/215/0001231804" onclick="nclk(event, 'home.newsflash', '', '')">
# <div class="cn_title_area">
# <h4 class="cn_title">'블랙 프라이데이' 1조 넘게 퍼담는 개미…외인 폭탄에 '역부족'</h4>
# <div class="cn_snippet">
# <div class="cn_journal_wrap">
# <div class="cn_name">한국경제TV</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
# <span class="blind">속보 닫기</span>
# </button>
# </div>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/469" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2025/03/07/logo_469_100_20250307145719.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18"/>
# </div>
# <em class="cnf_journal_name">한국일보</em>
# <span class="cnf_journal_sub">11월 21일 11:27</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="469" data-office_name="한국일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000898813" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/469/2025/11/21/898813.jpg?type=nf168_108&amp;ut=20251121110908" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[속보] '채상병 수사외압' 尹·이종섭·조태용 등 12명 불구속기소</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000898763" onclick="nclk(event, 'home.editnfimg', '', '')">빠루까지 동원된 '동물 국회' 전원 유죄인데··· 의원직도 전원 유지</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000898801" onclick="nclk(event, 'home.editnfimg', '', '')">박철우 서울중앙지검장 첫 출근... "檢 항소포기 반발 이해, 정치권도 이해했으면"</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000898757" onclick="nclk(event, 'home.editnfimg', '', '')">"제철 미역·굴 구독 서비스 대박 예감" 특성화 사업에 섬 마을 활기 반전</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/607" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/607/2025/03/07/logo_607_100_20250307145627.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">뉴스타파</em>
# <span class="cnf_journal_sub">11월 21일 11:34</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="607" data-office_name="뉴스타파" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003038" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/607/2025/11/21/3038.jpg?type=nf168_108&amp;ut=20251121113509" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[타파의 시선] 법이라는 가위를 든 엿장수 : 3대 특검 영장 기각 논란</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003037" onclick="nclk(event, 'home.editnfimg', '', '')">[주간 뉴스타파] 이재명 정부가 떠 안은 ‘좀비 발전소’ 민자 석탄</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003036" onclick="nclk(event, 'home.editnfimg', '', '')">아베 같은 윤석열, 자민당 같은 국민의힘을 꿈꿨나</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003035" onclick="nclk(event, 'home.editnfimg', '', '')">국제범죄조직 돈세탁 통로된 세계 최대 코인거래소</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/015" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2025/03/07/logo_015_100_20250307145644.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">한국경제</em>
# <span class="cnf_journal_sub">11월 21일 11:38</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="015" data-office_name="한국경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005214281" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/015/2025/11/21/5214281.jpg?type=nf168_108&amp;ut=20251121081509" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">"40분 더 자고 출근해요"…8년 만에 집값 9억 뛴 동네 [집코노미-집집폭폭]</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005214384" onclick="nclk(event, 'home.editnfimg', '', '')">주담대 줄줄이 막힌다…연말 '대출 한파'에 속타는 실수요자</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005214344" onclick="nclk(event, 'home.editnfimg', '', '')">"100억 든다고요? 제가 낼게요"…은마아파트에 무슨 일이</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005214409" onclick="nclk(event, 'home.editnfimg', '', '')">조국, 부산시장 출마설에 "전당대회 이후 마지막에 결정"</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/087" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2025/03/07/logo_087_100_20250307145607.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">강원일보</em>
# <span class="cnf_journal_sub">11월 21일 11:40</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="087" data-office_name="강원일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001156430" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/087/2025/11/21/1156430.jpg?type=nf168_108&amp;ut=20251121113908" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[속보]춘천서 자신 소유 승용차에 깔린 60대 사망</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001156422" onclick="nclk(event, 'home.editnfimg', '', '')">휴대전화 새 기종으로 교체해주지 않는다는 이유로 자기 집에 불 지른 여중생 방화 혐의로 입건</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001156423" onclick="nclk(event, 'home.editnfimg', '', '')">치매 앓던 80대 이웃집 창고서 숨진지 일주일 만에 발견…검시 결과 저체온증으로 파악</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001156232" onclick="nclk(event, 'home.editnfimg', '', '')">쿠팡 "고객 4천500여명 이름·이메일·전화번호·주소 등 개인정보 노출"…정부에 신고</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/002" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/002/2025/03/07/logo_002_100_20250307145612.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">프레시안</em>
# <span class="cnf_journal_sub">11월 21일 11:34</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="002" data-office_name="프레시안" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002415238" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/002/2025/11/20/2415238.jpg?type=nf168_108&amp;ut=20251120102814" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">김용현에 책임 떠넘긴 윤석열 "나는 군을 조금만 투입하라고 했는데 왜 여기저기…"</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002415460" onclick="nclk(event, 'home.editnfimg', '', '')">국민의힘 '대장동 공세' 보름째…"'김문기 법' 입법 추진"</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002415410" onclick="nclk(event, 'home.editnfimg', '', '')">공수처, 지귀연 부장판사 압색 돌입…휴대전화 사용 기록 등 조사 대상</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002415448" onclick="nclk(event, 'home.editnfimg', '', '')">특검, '김건희 뇌물 의혹' 로저비비에 압수수색…국힘 김기현 부인 조만간 소환할 듯</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/055" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2025/03/26/logo_055_100_20250326142328.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">SBS</em>
# <span class="cnf_journal_sub">11월 21일 11:50</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="055" data-office_name="SBS" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001309829" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/055/2025/11/21/1309829.jpg?type=nf168_108&amp;ut=20251121113347" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# <span class="comp_ico_movie"><span class="blind">영상</span></span>
# </div>
# <strong class="cnf_news_title">이집트 대통령도 놀란 발언?…"황당한 계엄 무혈 혁명으로 회복" [바로이뉴스]</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001309847" onclick="nclk(event, 'home.editnfimg', '', '')">"사형이야! 싹 다 잡아들여?" 폭발…트럼프 성나게 한 영상 [자막뉴스]</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001309872" onclick="nclk(event, 'home.editnfimg', '', '')">"차 밑에 사람이" 숨진 채 발견…자기 차량에 깔렸다</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001309831" onclick="nclk(event, 'home.editnfimg', '', '')">"낙하산 내놔" 비상문 향해 돌진…운항 중 항공기서 난동</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/032" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2025/03/07/logo_032_100_20250307145554.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">경향신문</em>
# <span class="cnf_journal_sub">11월 21일 11:29</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="032" data-office_name="경향신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003410273" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/032/2025/11/21/3410273.jpg?type=nf168_108&amp;ut=20251121104709" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">박철우 중앙지검장 “경찰 사법통제와 보완수사로 검찰 존재의의 인정받아야”</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003410280" onclick="nclk(event, 'home.editnfimg', '', '')">[속보]특검, ‘채상병 수사 외압’ 윤석열 등 12명 기소···“윤 격노에 따라 수사 결과 변경”</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003410265" onclick="nclk(event, 'home.editnfimg', '', '')">김병기 “윤석열 재판 발언 충격적···입 다물고 감옥에서 참회하며 살라”</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003410254" onclick="nclk(event, 'home.editnfimg', '', '')">“엄마·아빠가 새 휴대폰 안 사줘서”···중학생이 아파트에 불 질러</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/277" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2025/03/12/logo_277_100_20250312105338.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">아시아경제</em>
# <span class="cnf_journal_sub">11월 21일 11:50</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="277" data-office_name="아시아경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005682548" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/277/2025/11/21/5682548.jpg?type=nf168_108&amp;ut=20251121104911" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">영업익115% 상승 '역대급 실적' 해외서 더 주목…209만원 리포트까지 [양날개 편 삼성바이오]④</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005682761" onclick="nclk(event, 'home.editnfimg', '', '')">"서울 와서 명동·경복궁만 가니? '여기'가 찐이지"…잠실에 꽂힌 관광객들</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005682640" onclick="nclk(event, 'home.editnfimg', '', '')">"모델대회 맞아?"…중국서 우승자 체형 두고 공정성 시비 폭발</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005682479" onclick="nclk(event, 'home.editnfimg', '', '')">"변기에 자꾸 넣으니 매년 수천 억 낭비"…물티슈 아예 판매금지 시킨 영국</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/088" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/088/2025/03/07/logo_088_100_20250307145609.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">매일신문</em>
# <span class="cnf_journal_sub">11월 21일 11:47</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="088" data-office_name="매일신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000982601" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/088/2025/11/21/982601.jpg?type=nf168_108&amp;ut=20251121111815" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[속보] 내란특검, 한덕수 전 총리 소환…'헌법재판관 미임명 의혹'</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000982584" onclick="nclk(event, 'home.editnfimg', '', '')">李 대통령 지지율 다시 60%대, 대장동·재판회피 등 여파 남아</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000982575" onclick="nclk(event, 'home.editnfimg', '', '')">"염전노예 신안, 자작극"…여객선 좌초사고에 악성댓글 확산</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000982577" onclick="nclk(event, 'home.editnfimg', '', '')">송지효, 부친 '빚투' 의혹에 "협박 반복되면 법적 조치"</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/018" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2025/03/07/logo_018_100_20250307145653.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">이데일리</em>
# <span class="cnf_journal_sub">11월 21일 11:45</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="018" data-office_name="이데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006169267" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/11/21/6169267.jpg?type=nf168_108&amp;ut=20251121105709" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">“빚투 남 얘기 아냐”…근무시간에 주식하는 직장인들</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006169316" onclick="nclk(event, 'home.editnfimg', '', '')">삼성 대표이사가 메모리·갤럭시 '겸직'…예상 깬 인사 포석은</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006169271" onclick="nclk(event, 'home.editnfimg', '', '')">AI 거품 붕괴 대비?…오라클 ‘부도 위험’에 베팅 늘어</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006169049" onclick="nclk(event, 'home.editnfimg', '', '')">뚱뚱하면 퇴출이라더니…살 빼려는 미군들, 이것까지 강행</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/030" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/030/2025/03/07/logo_030_100_20250307145551.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">전자신문</em>
# <span class="cnf_journal_sub">11월 21일 11:01</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="030" data-office_name="전자신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003372712" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/030/2025/11/21/3372712.jpg?type=nf168_108&amp;ut=20251121102511" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">삼성전자, 조직 안정 선택 … 전영현·노태문, 2인 대표 체제 유지</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003372640" onclick="nclk(event, 'home.editnfimg', '', '')">18세로 회춘하려고 수십억 퍼붓던 美 억만장자, 돌고돌아 결국 '아침 커피?'</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003372724" onclick="nclk(event, 'home.editnfimg', '', '')">“돈 좀 벌더니 거만해졌어”... 北, 사업가 부부 공개처형</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003372636" onclick="nclk(event, 'home.editnfimg', '', '')">제네시스, 첫 고성능車 'GV60 마그마' 공개</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/293" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/293/2025/03/07/logo_293_100_20250307145632.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">블로터</em>
# <span class="cnf_journal_sub">11월 21일 11:13</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="293" data-office_name="블로터" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000075361" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/293/2025/11/21/75361.jpg?type=nf168_108&amp;ut=20251121073706" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[금융CEO 인사 시즌] 김인 새마을금고중앙회장 '연임' 굳히기…1기 성과 조명</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000075360" onclick="nclk(event, 'home.editnfimg', '', '')">[데스크시각] 'AI 시대' 한국형 VFX 생존법</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000075371" onclick="nclk(event, 'home.editnfimg', '', '')">여신금융 업계, 묵혔던 '규제 완화'에 반색…기대 효과 살펴보니</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000075370" onclick="nclk(event, 'home.editnfimg', '', '')">[방산 R&amp;D 리포트] 한화에어로, 'R&amp;D 5670억' 방산 3사 합계 웃돌아</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/094" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/094/2025/03/07/logo_094_100_20250307145631.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">월간산</em>
# <span class="cnf_journal_sub">11월 21일 08:52</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="094" data-office_name="월간산" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013100" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/094/2025/11/21/13100.jpg?type=nf168_108&amp;ut=20251121075015" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">알프스 설원에서 스키…믿어지지 않아! [스위스 융프라우 스키]</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013099" onclick="nclk(event, 'home.editnfimg', '', '')">아이거 북벽의 거대한 감동, 2시간 걷기에 담다 [스위스 융프라우 64번 코스 클라이네 샤이텍-알피글렌 하이킹]</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013098" onclick="nclk(event, 'home.editnfimg', '', '')">"‌실적 스트레스에서 풀려난 지금, 산이 내게 제2인생을 열어줬다" [박동기 전 롯데월드 대표]</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013097" onclick="nclk(event, 'home.editnfimg', '', '')">중국이 북한에 돈 내고 빌린 백두산 최고 전망대 [배 타고 가는 백두산 下]</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/053" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/053/2025/03/07/logo_053_100_20250307145635.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">주간조선</em>
# <span class="cnf_journal_sub">11월 21일 11:28</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="053" data-office_name="주간조선" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000053684" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/053/2025/11/21/53684.jpg?type=nf168_108&amp;ut=20251121111508" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">李대통령 지지율 60%..."외교는 ↑, 재판은 ↓"</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000053682" onclick="nclk(event, 'home.editnfimg', '', '')">'AI 거품론'에 흔들린 증시…코스피 4000·3900선 연달아 붕괴</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000053671" onclick="nclk(event, 'home.editnfimg', '', '')">쿠팡서 고객 정보 털렸다...4500명 이름·주소·주문내역까지 노출</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000053672" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 1위·한동훈 2위...뜻밖의 무대에서 펼쳐진 경쟁의 승자는?</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/079" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/079/2025/04/24/logo_079_100_20250424111642.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">노컷뉴스</em>
# <span class="cnf_journal_sub">11월 21일 11:53</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="079" data-office_name="노컷뉴스" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004088387" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/079/2025/11/21/4088387.jpg?type=nf168_108&amp;ut=20251121110909" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[속보]해병특검 "尹, '임성근 제외하라' 개별적·구체적 지시"</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004088364" onclick="nclk(event, 'home.editnfimg', '', '')">'항소포기' 여진에도…李 60% 與 43% 지지[갤럽]</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004088370" onclick="nclk(event, 'home.editnfimg', '', '')">박철우 중앙지검장 "검찰 박탈감·자괴감 들 것…저 또한 억울"</a>
# </li>
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004088256" onclick="nclk(event, 'home.editnfimg', '', '')">"UAE 보기에 부끄러워서"…아크부대 '구식장비 직언' 화제[영상]</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_brick_item _channel_main_news_card_wrapper">
# <div class="comp_news_feed comp_news_none">
# <div class="cnf_journal_area">
# <a class="cnf_journal" href="https://media.naver.com/press/214" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cnf_journal_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/214/2025/03/07/logo_214_100_20250307145647.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
# </img></div>
# <em class="cnf_journal_name">MBC</em>
# <span class="cnf_journal_sub">11월 21일 11:49</span>
# </a>
# <button class="cnf_btn_subscription _subscribe_btn" data-office_id="214" data-office_name="MBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button"><span class="blind">구독</span></button>
# </div>
# <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001463222" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cnf_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/214/2025/11/21/1463222.jpg?type=nf168_108&amp;ut=20251121111911" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
# </div>
# <strong class="cnf_news_title">[속보] '내란'특검, '헌법재판관 임명 보류' 한덕수 전 국무총리 조사</strong>
# </a>
# <ul class="cnf_news_list">
# <li class="cnf_news_item">
# <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001463233" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 조희대 대법원장, 법원 직원들의 법원장 평가에서 꼴찌</a>
# </li>
# <li class="cnf_news_item">
# ...
# <picture>
# <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320.png"/>
# <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="light_type" data-src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner.png" loading="lazy" width="100%"/>
# </picture>
# <picture>
# <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320_dark.png"/>
# <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="dark_type" data-src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_dark.png" loading="lazy" width="100%"/>
# </picture>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# </div>
# </div>
# </section>
# <section class="main_aside _aside_wrapper">
# <div class="main_aside_inner _aside_content">
# <h3 class="blind">구독</h3>
# <div class="_aside"></div>
# <script>
# doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.title = "구독 및 추천 채널";
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
# </script>
# </div>
# </section>
# <div class="layer_toast" style="display: none"></div>
# <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
# <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button"></button>
# </div>
# </div>
# </div>
#
# <!-- //ct -->
# <hr/>
# <div class="mp_footer">
# <div class="f_maininfo">
# <div class="f_maininfoinner">
# <a class="r_pg_top _go_top" href="javascript:topPage();" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">맨위로</a>
# <footer role="contentinfo">
# <p class="u_cr">
# <span class="u_ftm _footer_login">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a></span>
# </span>
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://news.naver.com/ombudsman","p":"https://news.naver.com/ombudsman"}' href="https://news.naver.com/ombudsman" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}' href="https://help.naver.com/alias/news/news_001.naver" onclick="nclk(event,'fot.report','','');">오류신고</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}' href="https://help.naver.com/alias/news/news_007.naver" onclick="nclk(event,'fot.help','','');">고객센터</a></span>
# </span>
# <span class="cr_rule">
# <span class="cr_rulea">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_presscopy">
#     각 언론사가 직접 콘텐츠를 편집합니다.
#
# </span>
# <span class="u_copyright">이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</span>
# <span class="u_naverlogo"><a class="u_naverlogo_a" data-mpurl='{"m":"https://www.navercorp.com/","p":"https://www.navercorp.com/"}' href="https://www.navercorp.com/" id="nhnLink" onclick="nclk(event,'fot.navercorp','','');">NAVER</a></span>
# </p>
# </footer>
# </div>
# </div>
# </div>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251029_123353/js/generated/news.mobile.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251029_123353/js/generated/pressmain.dependency.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var config = {
#         "neloCollectorUrl": "https://kr-col-ext.nelo.navercorp.com/_store",
#         "projectName": "P638fcb_news-mobile-front",
#         "host": "real"
#     }
#
#     try{
#         neloSender.init(config);
#     }catch(e){}
# </script>
# <script type="text/javascript">
# /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_cra" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a></span>')
#             }else {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="'+loginUrl+'" class="u_cra" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a></span>')
#             }
#         }
#     }
# });
# </script>
# <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#     {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
# </script>
# <script type="text/javascript">
#     try {
#         FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#         FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#         FeedAccordionIssueCard($('._issue_feed_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] FeedCard 스크립트 오류 " + e);
#     }
#
#     try {
#         BrickGridForEditByPress($("._brick_gid_wrapper"));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] BrickGridForEditByPress 스크립트 오류 " + e);
#     }
#
#     try {
#         PressMainStatusCard($('._press_main_status_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] PressMainStatusCard 스크립트 오류 " + e);
#     }
#
#     try {
#         NewsFlashCard($('._newsflash_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] NewsFlashCard 스크립트 오류 " + e);
#     }
#
#     try {
#
#
#         window.gladsdk.cmd.push(function () {
#             var adSlots = [];
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox"));
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox_secondary"));
#
#             var adDedupManager = window.gladsdk.setAdDeduplication("pressmain_ad");
#             if (isBackForwardNavigated()) {
#                 adDedupManager.restoreAds(adSlots);
#             } else {
#                 adDedupManager.displayAds(adSlots);
#             }
#
#
#             window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").hide();
#             });
#
#             window.gladsdk.addEventListener(window.gladsdk.event.AD_LOADED, function (ad) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").show();
#             });
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] 광고 호출 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._channel_news_card_wrapper').each(function () {
#             var wrapper = $(this);
#             ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelNewsCard 스크립트 오류" + e);
#     }
#
#     try {
#         ChannelMainNewsCard($('._channel_main_news_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelMainNewsCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#         SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SubscribeBannerCard 스크립트 오류 " + e);
#     }
#
#     try {
#         WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] WeeklySpecialReportCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._tab_card_wrapper').each(function () {
#             var wrapper = $(this);
#             TabCard(wrapper);
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] TabCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._horizontal_card_wrapper').each(function () {
#             var wrapper = $(this);
#             HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] HorizontalTypeCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SpecialReportCard 스크립트 오류 " + e);
#     }
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#     // Impression
#     try {
#         news.Impression.getInstance().init();
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] Impression init 스크립트 오류 " + e);
#     }
#
#     new news.ImageLazyLoader().load("img[data-src]");
# </script>
# <script>
#     var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2025112111";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
# </script>
# <script>
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
# </script>
# <script>
# doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
# </script>
# <!-- LCS -->
# <script type="text/javascript">
#
# function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
# </script>
# <script type="text/javascript">
#     window.ntm_news = window.ntm_news || [];
#
#     doAfterLoadEnd(function () {
#         var ntmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
#
#
#
#
#         ntmInit(ntmUrl);
#     });
# </script>
# <script type="text/javascript">
#     // NLog pageview 전송
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jQuery(window).on(eventType, function() {
#         var sti = "";
#         var gdid = "";
#
#
#
#
#
#
#                 if (isMobileDevice()) {
#                     // mobile
#
#                         sti = "m_news";
#
#                 } else {
#                     // pc
#
#                 }
#
#
#
#         // ma 전송
#         try {
#             initMa();
#         } catch (e) {
#         }
#
#         ntmCustomPageViewSend({
#             sti: sti,
#             gdid: gdid
#         });
#     });
# </script>
# <!-- //LCS -->
# <div id="videoWrap"></div>
# </body>
# </html>

# %%
# 4. CSS 선택자(.Nitem_link_menu)에 맞는 요소 모두 찾기
items = soup.select(".Nitem_link_menu")
items
# Out:
# [<span class="Nitem_link_menu">언론사별</span>,
#  <span class="Nitem_link_menu">정치</span>,
#  <span class="Nitem_link_menu">경제</span>,
#  <span class="Nitem_link_menu">사회</span>,
#  <span class="Nitem_link_menu">생활/문화</span>,
#  <span class="Nitem_link_menu">IT/과학</span>,
#  <span class="Nitem_link_menu">세계</span>,
#  <span class="Nitem_link_menu">랭킹</span>,
#  <span class="Nitem_link_menu">신문보기</span>,
#  <span class="Nitem_link_menu">오피니언</span>,
#  <span class="Nitem_link_menu">TV</span>,
#  <span class="Nitem_link_menu">팩트체크</span>,
#  <span class="Nitem_link_menu">알고리즘 안내</span>,
#  <span class="Nitem_link_menu">정정보도 모음</span>]

# %%
len(items)
# Out:
# 14

# %%
items[0].text
# Out:
# '언론사별'

# %%
for item in items:
    # print(item.text)
    print(item.get_text())
# Out:
# 언론사별
# 정치
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 알고리즘 안내
# 정정보도 모음
