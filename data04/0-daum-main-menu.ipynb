# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
con = request.urlopen('https://top.cafe.daum.net/')
con
#http response(header + body)
#header : http result status code
#         (ok: 200, not found: 404, error: 500, permission: 403)

# %%
con.status #status code
# Out:
# 200

# %%
doc = BeautifulSoup(con, 'html.parser')
#doc

# %%
doc
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="xfAsz914fZL-Hz0TPlzNbfP2aJH7w5ZMMxOy1c39USM" name="google-site-verification"/>
# <meta content="width=1240" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="모든 이야기의 시작 - Daum 카페" property="og:title"/>
# <meta content="http://top.cafe.daum.net" property="og:url"/>
# <meta content="https://t1.daumcdn.net/cafe_image/cafe_meta_image_240307.png" property="og:image"/>
# <meta content="모든 이야기의 시작, 다음 카페" property="og:description"/>
# <title>카페홈 - Daum 카페</title>
# <meta content="모든 이야기의 시작, 다음 카페" name="description"/>
# <link href="//t1.daumcdn.net/cafe_cj/font/spoqa_sans_number_english_20190404/stylesheet.css" media="all" onload="if(media!='all')media='all'" rel="stylesheet" type="text/css"/>
# ...

# %%
# HTML 구조 확인 - 전체 HTML 출력
# print(doc.prettify()[:5000])  # 처음 5000자만 출력
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="xfAsz914fZL-Hz0TPlzNbfP2aJH7w5ZMMxOy1c39USM" name="google-site-verification"/>
#   <meta content="width=1240" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="모든 이야기의 시작 - Daum 카페" property="og:title"/>
#   <meta content="http://top.cafe.daum.net" property="og:url"/>
#   <meta content="https://t1.daumcdn.net/cafe_image/cafe_meta_image_240307.png" property="og:image"/>
#   <meta content="모든 이야기의 시작, 다음 카페" property="og:description"/>
#   <title>
#    카페홈 - Daum 카페
#   </title>
#   <meta content="모든 이야기의 시작, 다음 카페" name="description"/>
#   <link href="//t1.daumcdn.net/cafe_cj/font/spoqa_sans_number_english_20190404/stylesheet.css" media="all" onload="if(media!='all')media='all'" rel="stylesheet" type="text/css"/>
# ...

# %%
# 다양한 선택자로 시도
print("=== 다양한 선택자 시도 ===")

# 시도 1: category_list 클래스 찾기
img_test1 = doc.select('a.link_item')

img_test1
# Out:
# === 다양한 선택자 시도 ===
# [<a class="link_item" href="/_c21_/home">홈</a>,
#  <a class="link_item table_gnb" href="//table.cafe.daum.net">테이블</a>,
#  <a class="link_item" href="/_c21_/fancafe_list">팬카페</a>,
#  <a class="link_item" href="/_c21_/cafe_ranking">카페랭킹</a>,
#  <a class="link_item" href="/_c21_/my_cafe">내카페</a>]

# %%
type(img_test1)
# Out:
# bs4.element.ResultSet

# %%
#리스트의 갯수
len(img_test1)
# Out:
# 5

# %%
img_test1[0]
# Out:
# <a class="link_item" href="/_c21_/home">홈</a>

# %%
img_test1[0].text
# Out:
# '홈'

# %%
for one in img_test1:
    print(one.text)
# Out:
# 홈
# 테이블
# 팬카페
# 카페랭킹
# 내카페

# %%
anav_list = []

# %%
for one in img_test1:
    anav_list.append(one.text)

# %%
anav_list
# Out:
# ['홈', '테이블', '팬카페', '카페랭킹', '내카페']

# %%
# 다양한 방법으로 제목 추출 시도
print("=== 제목 추출 시도 (여러 선택자) ===\n")

# # 방법 1: 기존 코드
# p_tag_list = doc.select('p.tit')
# print(f"1. 'p.tit' 결과: {len(p_tag_list)}개")

# # 방법 2: h 태그들
# h_list = doc.select('h2, h3')
# print(f"2. 'h2, h3' 결과: {len(h_list)}개")

# # 방법 3: span 태그 + 클래스
# span_list = doc.select('span[class*="tit"], span[class*="title"], span[class*="name"]')
# print(f"3. span with tit/title/name: {len(span_list)}개")

# 방법 4: a 태그 (링크 텍스트)
a_items = doc.select('a[class*="item"], a[class*="album"], a[class*="track"]')
print(f"4. a with item/album/track: {len(a_items)}개")

# # 방법 5: div 기반 검색
# div_list = doc.select('div[class*="title"], div[class*="name"], div[class*="tit"]')
# print(f"5. div with title/name/tit: {len(div_list)}개")


# 최선의 결과 출력
# Out:
# === 제목 추출 시도 (여러 선택자) ===
#
# 4. a with item/album/track: 5개

# %%
result = []
for x in a_items:
    print(x.text)
    result.append(x.text)
result
# Out:
# 홈
# 테이블
# 팬카페
# 카페랭킹
# 내카페
# ['홈', '테이블', '팬카페', '카페랭킹', '내카페']
