# %%
import requests

headers = {
    'accept': 'application/json',
    'Authorization': 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg==',
}

params = (
    ('page', '1'),
    ('perPage', '1000'),
    ('serviceKey', 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg=='),
)

## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
response = requests.get('https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4', headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
json_total = response.json()
json_total
# Out:
# {'currentCount': 1000,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
import pickle
with open('covid-data-gokr.json', 'wb') as fp:
    pickle.dump(json_total, fp)

# %%
with open('covid-data-gokr.json', 'rb') as fp:
    json_data = pickle.load(fp)
json_data
# Out:
# {'currentCount': 1000,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
data = json_data['data']
data[:5]
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
print(len(data))
print(data[0])
print('제목-->', data[0]['제목'])
print('본문-->', data[0]['본문'])
# Out:
# 1000
# {'개체명(기업기관)': None, '개체명(인물)': None, '개체명(지역)': None, '기고자': '당직자공용 기자', '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews", '사건_사고 분류1': None, '사건_사고 분류2': None, '사건_사고 분류3': None, '언론사': '헤럴드경제', '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027', '일자': '2020-02-01', '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어", '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001', '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명', '통합 분류1': '사회>의료_건강', '통합 분류2': None, '통합 분류3': None, '특성추출': '신종코,추가,환자,확진'}
# 제목--> [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 본문--> [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews

# %%
for one in data:
    print(one)
# Out:
# {'개체명(기업기관)': None, '개체명(인물)': None, '개체명(지역)': None, '기고자': '당직자공용 기자', '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews", '사건_사고 분류1': None, '사건_사고 분류2': None, '사건_사고 분류3': None, '언론사': '헤럴드경제', '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027', '일자': '2020-02-01', '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어", '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001', '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명', '통합 분류1': '사회>의료_건강', '통합 분류2': None, '통합 분류3': None, '특성추출': '신종코,추가,환자,확진'}
# ...

# %%
with open('covid-sub-data-gokr.json', 'wb') as fp:
    pickle.dump(data, fp)

# %%
with open('covid-sub-data-gokr.json', 'rb') as fp:
    json_sub_data = pickle.load(fp)
json_sub_data[:2]
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.DataFrame(json_sub_data)
df_test
# Out:
#                                   개체명(기업기관) 개체명(인물) 개체명(지역)            기고자  \
# 0                                      None    None    None       당직자공용 기자
# 1                                      None    None    None            이상규
# 2                                      None    None    None            황재희
# 3                                      None    None    None  이미경(capital);
# 4                                      None    None    None            김봄이
# ..                                      ...     ...     ...            ...
# 995  정부세종청사 보건복지부 중앙사고수습본부 행정안전부 중수본 질병관리본부    None    None         박세원 기자
# 996                질병관리본부 충남대병원 코젠바이오텍 식약처장    None    None         선정화 기자
# 997                             인제군문화재단 EBS    None    None            김보경
# 998                                     파주시    None    None            박상돈
# 999                              정부 주택산업연구원    None    None            김현우
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   개체명(기업기관)  574 non-null    object
#  1   개체명(인물)    0 non-null      object
#  2   개체명(지역)    0 non-null      object
#  3   기고자        939 non-null    object
#  4   본문         1000 non-null   object
#  5   사건_사고 분류1  0 non-null      object
#  6   사건_사고 분류2  0 non-null      object
#  7   사건_사고 분류3  0 non-null      object
#  8   언론사        1000 non-null   object
#  9   원본주소       955 non-null    object
#  10  일자         1000 non-null   object
#  11  제목         1000 non-null   object
#  12  주소         1000 non-null   object
#  13  키워드        1000 non-null   object
#  14  통합 분류1     791 non-null    object
#  15  통합 분류2     0 non-null      object
#  16  통합 분류3     0 non-null      object
#  17  특성추출       1000 non-null   object
# dtypes: object(18)
# memory usage: 140.8+ KB

# %%
df_test.shape
# Out:
# (1000, 18)

# %%
df_test.drop(columns=['개체명(기업기관)','개체명(인물)','개체명(지역)',
                      '사건_사고 분류1','사건_사고 분류2','사건_사고 분류3',
                      '통합 분류2','통합 분류3'],
                     inplace=True
            )
df_test[:2]
# Out:
#         기고자                                                 본문    언론사  \
# 0  당직자공용 기자  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  헤럴드경제
# 1       이상규  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...   매일경제
#
#                                                 원본주소          일자  \
# 0  http://biz.heraldcorp.com/view.php?ud=20200201...  2020-02-01
# 1  http://news.mk.co.kr/newsRead.php?no=104142&ye...  2020-02-01
#
#                                           제목  \
# 0           [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시
#
#                                                   주소  \
# 0  http://www.bigkinds.or.kr/news/newsDetailView....
# 1  http://www.bigkinds.or.kr/news/newsDetailView....
#
#                                             키워드    통합 분류1                 특성추출
# 0          신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명  사회>의료_건강         신종코,추가,환자,확진
# 1  신종코,확진,70명,검사,접촉자,감시,속보,신종코,확진,70명,검사,접촉자,감시  사회>의료_건강  접촉자,신종코,감시,확진,검사,속보

# %%
df_test['기고자'][:5]
# Out:
# 0         당직자공용 기자
# 1              이상규
# 2              황재희
# 3    이미경(capital);
# 4              김봄이
# Name: 기고자, dtype: object

# %%
df_test['본문'][:5]
# Out:
# 0    [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...
# 1    [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...
# 2    [그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으...
# 3    [속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자...
# 4                          '신종코로나' 확진환자 1명 추가…국내 총 12명
# Name: 본문, dtype: object
