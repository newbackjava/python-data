# %%
import requests #파이썬에서 http통신을 할 수 있는 최근 라이브러리

# %%
# 주소?query=자동차
# http(header+body)
# http - 검색(get, header에 요청한 주소+전달값)

# http header에는 보통 인증정보 + 받을 데이터 형식 지정
header_data= {
    'accept': 'application/json',
    'Authorization': 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg==',
}

param_data = (
    ('page', '1'),
    ('perPage', '10'),
    ('serviceKey', 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg=='),
)

url = 'https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4'

response = requests.get(url, headers=header_data, params=param_data) 
response #response(http header+body, header(status, message))
# Out:
# <Response [200]>

# %%
json_data = response.text
#http의 body에 온 데이터를 json형태로 저장해라!
#python에서는 {키:값}형태가 딕셔너리(dict)형태로 저장함.
json_data
# Out:
# '{"currentCount":10,"data":[{"개체명(기업기관)":null,"개체명(인물)":null,"개체명(지역)":null,"기고자":"당직자공용 기자","본문":"[헤럴드경제] \'신종코로나\' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews","사건_사고 분류1":null,"사건_사고 분류2":null,"사건_사고 분류3":null,"언론사":"헤럴드경제","원본주소":"http://biz.heraldcorp.com/view.php?ud=20200201000027","일자":"2020-02-01","제목":"[속보] \'신종코로나\' 확진환자 1명 추가…12명으로 늘어","주소":"http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001","키워드":"신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명","통합 분류1":"사회\\u003e의료_건강","통합 분류2":null,"통합 분류3":null,"특성추출":"신종코,추가,환자,확진"},{"개체명(기업기관)":null,"개체명(인물)":null,"개체명(지역)":null,"기고자":"이상규","본문":"[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]","사건_사고 분류1":null,"사건_사고 분류2":null,"사건_사고 분류3":null,"언론사":"매일경제","원본주소":"http://news.mk.co.kr/newsRead.php?no=104142\\u0026year=2020","일자":"2020-02-01","제목":"[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시","주소":"http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100101.20200201142733001","키워드":"신종코,확진,7
# ...

# %%
json_data = response.json()
#http의 body에 온 데이터를 json형태로 저장해라!
#python에서는 {키:값}형태가 딕셔너리(dict)형태로 저장함.
json_data
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
json_data2 = response.text #http의 body에 있는 것 그대로 꺼내오겠음.
# json 형태의 str이 들어있음.
json_data2
# Out:
# '{"currentCount":10,"data":[{"개체명(기업기관)":null,"개체명(인물)":null,"개체명(지역)":null,"기고자":"당직자공용 기자","본문":"[헤럴드경제] \'신종코로나\' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews","사건_사고 분류1":null,"사건_사고 분류2":null,"사건_사고 분류3":null,"언론사":"헤럴드경제","원본주소":"http://biz.heraldcorp.com/view.php?ud=20200201000027","일자":"2020-02-01","제목":"[속보] \'신종코로나\' 확진환자 1명 추가…12명으로 늘어","주소":"http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001","키워드":"신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명","통합 분류1":"사회\\u003e의료_건강","통합 분류2":null,"통합 분류3":null,"특성추출":"신종코,추가,환자,확진"},{"개체명(기업기관)":null,"개체명(인물)":null,"개체명(지역)":null,"기고자":"이상규","본문":"[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]","사건_사고 분류1":null,"사건_사고 분류2":null,"사건_사고 분류3":null,"언론사":"매일경제","원본주소":"http://news.mk.co.kr/newsRead.php?no=104142\\u0026year=2020","일자":"2020-02-01","제목":"[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시","주소":"http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100101.20200201142733001","키워드":"신종코,확진,7
# ...

# %%
type(json_data)
# Out:
# dict

# %%
import pickle

# %%
# 예외처리(try~except)는 외부 자원을 연결할 때
# 외부 자원 : network(openapi, db), file, cpu(thread.sleep())
# 외부 자원연결할 때 파이썬과 외부 자원사이에 연결(stream, 강물)이 만들어짐.
# 스트림이 만들어지면 반드시 없애주어야함. close해주어야함.
# try:
#    file.open(파일명, "r"):
#      print(읽어온 데이터)
#    file.close()
# except:
#    print("문제가 생겼음")

# fp = file.open('covid-gokr.json', 'wb')
# fp.close()

# with라고 써주면 자동으로 close해줌.
with open('covid-gokr.json', 'wb') as fp:
    pickle.dump(json_data, fp)

# %%
with open('covid-gokr.json', 'rb') as fp:
    json_read_data = pickle.load(fp)

# %%
# json_read_data

# %%
json_read_data['currentCount']
# Out:
# 10

# %%
json_data['data'][:2]
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
data_values = json_data['data'] #data키에 대한 값은 리스트임.
len(data_values)
# Out:
# 10

# %%
data_values[0]
# Out:
# {'개체명(기업기관)': None,
#  '개체명(인물)': None,
#  '개체명(지역)': None,
#  '기고자': '당직자공용 기자',
#  '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#  '사건_사고 분류1': None,
#  '사건_사고 분류2': None,
#  '사건_사고 분류3': None,
#  '언론사': '헤럴드경제',
#  '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#  '일자': '2020-02-01',
#  '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#  '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#  '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#  '통합 분류1': '사회>의료_건강',
#  '통합 분류2': None,
#  '통합 분류3': None,
#  '특성추출': '신종코,추가,환자,확진'}

# %%
type(data_values)
# Out:
# list

# %%
one = data_values[0]
one['제목']
# Out:
# "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어"

# %%
data_values[0]['제목']
# Out:
# "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어"

# %%
one['언론사']
# Out:
# '헤럴드경제'

# %%
one['일자']
# Out:
# '2020-02-01'

# %%
one_row = []
one_row.append(data_values[0]['제목']) # 제목
one_row.append(data_values[0]['본문']) # 본문
one_row.append(data_values[0]['통합 분류1']) # 분야
one_row.append(data_values[0]['일자']) # 일자
one_row.append(data_values[0]['주소']) # 주소
one_row.append(data_values[0]['언론사']) # 언론사

print(one_row)
# Out:
# ["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어", "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews", '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001', '헤럴드경제']

# %%
total_row = [] #2차원리스틑 1차원리스트를 모아놓은 것.
#하나의  dict은 하나의 리스트임
#여러개는 [[row],[row],[row]] 2차원 리스트

for no in range(10): #0~9
    one_row = []
    one_row.append(data_values[no]['제목']) # 제목
    one_row.append(data_values[no]['본문']) # 본문
    one_row.append(data_values[no]['통합 분류1']) # 분야
    one_row.append(data_values[no]['일자']) # 일자
    one_row.append(data_values[no]['주소']) # 주소
    one_row.append(data_values[no]['언론사']) # 언론사

    print(one_row)

    total_row.append(one_row)
    
len(total_row)
# Out:
# ["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어", "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews", '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001', '헤럴드경제']
# ['[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시', '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]', '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100101.20200201142733001', '매일경제']
# ['[속보] 신종 코로나 확진자 12명…70명 검사 중', '[그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으로 확인됐다. 현재 검사 중인 사람은 총 70명이다. 황재희 기자 jhhwang', '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100851.20200201135243001', '아주경제']
# ["[속보] '신종코로나' 확진환자 1명 추가돼 국내 총 12명…하루 새 6명 늘어", "[속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자 capital 기사제보 및 보도자료 open", '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100601.20200201100004002', '한국경제']
# ...

# %%
import pandas as pd
import numpy as np

# %%
with open('covid-sub-data-dic.json', 'wb') as fp:
    pickle.dump(data_values, fp)

# %%
with open('covid-sub-data-dic.json', 'rb') as fp:
    json_sub_data_dic = pickle.load(fp)

# %%
df_test = pd.DataFrame(json_sub_data_dic) #[dic, dic, dic]
df_test[:2]
# Out:
#   개체명(기업기관) 개체명(인물) 개체명(지역)       기고자  \
# 0      None    None    None  당직자공용 기자
# 1      None    None    None       이상규
#
#                                                   본문 사건_사고 분류1 사건_사고 분류2  \
# 0  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...      None      None
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...      None      None
#
#   사건_사고 분류3    언론사                                               원본주소  \
# 0      None  헤럴드경제  http://biz.heraldcorp.com/view.php?ud=20200201...
# 1      None   매일경제  http://news.mk.co.kr/newsRead.php?no=104142&ye...
#
#            일자                                         제목  \
# 0  2020-02-01           [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 1  2020-02-01  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시
#
#                                                   주소  \
# 0  http://www.bigkinds.or.kr/news/newsDetailView....
# 1  http://www.bigkinds.or.kr/news/newsDetailView....
#
# ...

# %%
df_test2 = pd.DataFrame(
    total_row,
    columns=['제목', '본문', '통합 분류1', '일자', '주소', '언론사']
) 
df_test2.head(2)
# Out:
#                                           제목  \
# 0           [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시
#
#                                                   본문    통합 분류1          일자  \
# 0  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  사회>의료_건강  2020-02-01
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...  사회>의료_건강  2020-02-01
#
#                                                   주소    언론사
# 0  http://www.bigkinds.or.kr/news/newsDetailView....  헤럴드경제
# 1  http://www.bigkinds.or.kr/news/newsDetailView....   매일경제
