# %%
# Python3 샘플 코드 #


import requests

url = 'http://apis.data.go.kr/1262000/CountryCovid19SafetyServiceNew/getCountrySafetyNewsListNew'
params ={'serviceKey' : '63Jk4KYSAeT0Kif97Z6jQm7H4vk6jMJSJ29jfJB4wMtKA/DfN7igbdpFRmXbS+fopaXmPMqvIhJWeVLeuy2DXw==', 'returnType' : 'JSON', 'numOfRows' : '10', 'pageNo' : '1', 'cond[country_nm::EQ]' : '가나', 'cond[country_iso_alp2::EQ]' : 'GH' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"dataType":"JSON","items":{"item":[]},"numOfRows":10,"pageNo":1,"totalCount":0},"header":{"resultCode":"0","resultMsg":"\xec\xa0\x95\xec\x83\x81"}}}\n'
